# %%
from pyspark import SparkContext,SparkConf

# %%
conf= SparkConf().setAppName("RDDExample").setMaster("local")

# %%
conf

# %%
sc = SparkContext(conf=conf)

# %%
sc
# Out:
# <SparkContext master=local appName=RDDExample>

# %%
data = [1,2,3,4,5]
rdd = sc.parallelize(data)

# %%
sqaured_rdd=rdd.map(lambda x:x*x)
result=sqaured_rdd.collect()
print(result)
# Out:
# [1, 4, 9, 16, 25]

# %%
even_rdd=rdd.filter(lambda x:x%2==0)
result=even_rdd.collect()
print(result)
# Out:
# [2, 4]
